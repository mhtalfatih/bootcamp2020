# %%
import pandas as pd

# %%
data = 'DDS.csv'

# %%
data_df = pd.read_csv(data)
data_df
# Out:
#        disasterNumber  ihProgramDeclared  iaProgramDeclared  \
# 0                   1                  0                  1
# 1                   2                  0                  1
# 2                   3                  0                  1
# 3                   6                  0                  1
# 4                   4                  0                  1
# ...               ...                ...                ...
# 51036            4478                  0                  0
# 51037            4478                  0                  0
# 51038            4478                  0                  0
# 51039            4478                  0                  0
# 51040            4478                  0                  0
#
#        paProgramDeclared  hmProgramDeclared state           declarationDate  \
# 0                      1                  1    GA  1953-05-02T00:00:00.000Z
# 1                      1                  1    TX  1953-05-15T00:00:00.000Z
# ...

# %%
df = data_df[['disasterNumber','state', 'fyDeclared','disasterType','incidentType','title','declaredCountyArea']]
df
# Out:
#        disasterNumber state  fyDeclared disasterType     incidentType  \
# 0                   1    GA        1953           DR          Tornado
# 1                   2    TX        1953           DR          Tornado
# 2                   3    LA        1953           DR            Flood
# 3                   6    MI        1953           DR          Tornado
# 4                   4    MI        1953           DR          Tornado
# ...               ...   ...         ...          ...              ...
# 51036            4478    MS        2020           DR  Severe Storm(s)
# 51037            4478    MS        2020           DR  Severe Storm(s)
# 51038            4478    MS        2020           DR  Severe Storm(s)
# 51039            4478    MS        2020           DR  Severe Storm(s)
# 51040            4478    MS        2020           DR  Severe Storm(s)
#
#                                                    title   declaredCountyArea
# ...
