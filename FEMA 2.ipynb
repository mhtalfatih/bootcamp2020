# %%
import pandas as pd

# %%
data = 'state county.csv'

# %%
data_df = pd.read_csv(data)
data_df.head()
# Out:
#    Unnamed: 0 femaDeclarationString  disasterNumber state declarationType  \
# 0           0               DR-4-MI               4    MI              DR
# 1           1               DR-2-TX               2    TX              DR
# 2           2               DR-9-TX               9    TX              DR
# 3           3              DR-11-NH              11    NH              DR
# 4           4               DR-6-MI               6    MI              DR
#
#             declarationDate  fyDeclared incidentType  \
# 0  1953-06-02T04:00:00.000Z        1953      Tornado
# 1  1953-05-15T04:00:00.000Z        1953      Tornado
# 2  1953-06-19T04:00:00.000Z        1953        Flood
# 3  1953-07-02T04:00:00.000Z        1953         Fire
# 4  1953-06-09T04:00:00.000Z        1953      Tornado
#
#            declarationTitle  ihProgramDeclared  ...  disasterCloseoutDate  \
# 0                   TORNADO                  0  ...                   NaN
# ...

# %%
df =data_df [['disasterNumber','fipsStateCode','fyDeclared','declarationType','incidentType','fipsCountyCode',('state county')]]
df.head()
# Out:
#    disasterNumber  fipsStateCode  fyDeclared declarationType incidentType  \
# 0               4             26        1953              DR      Tornado
# 1               2             48        1953              DR      Tornado
# 2               9             48        1953              DR        Flood
# 3              11             33        1953              DR         Fire
# 4               6             26        1953              DR      Tornado
#
#    fipsCountyCode state county
# 0               0         26,0
# 1               0         48,0
# 2               0         48,0
# 3               0         33,0
# 4               0         26,0

# %%
df.to_csv('disaster FEMA2.csv')
